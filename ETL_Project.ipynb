# %%
import pandas as pd
from sqlalchemy import create_engine
import csv

# %%
SaaS_data = "Resources/latka_web_data.csv"
SaaS_df = pd.read_csv(SaaS_data)
SaaS_df.head()
# Out:
#    financials.arpu_max  financials.arpu_min  financials.arr_max  \
# 0               1899.0               1899.0          15951600.0
# 1               5000.0               5000.0           4800000.0
# 2                 19.0                 19.0          14400000.0
# 3               2000.0               2000.0           1000000.0
# 4                150.0                100.0         100000000.0
#
#    financials.arr_min  financials.cac_max  financials.cac_min  \
# 0          15951600.0                40.0                40.0
# 1           4200000.0              9000.0              9000.0
# 2          14400000.0               600.0                60.0
# 3            624000.0                 NaN                 NaN
# 4                 NaN               900.0               750.0
#
#                      financials.created_at  financials.gross_churn_max  \
# 0  Wed Feb 21 2018 11:57:07 GMT+0000 (UTC)                         6.0
# 1  Fri Feb 23 2018 17:15:59 GMT+0000 (UTC)                         1.0
# 2  Tue Oct 24 2017 22:58:12 GMT+0000 (UTC)                         6.0
# 3  Tue Feb 27 2018 15:44:13 GMT+0000 (UTC)                         1.0
# 4  Fri Feb 23 2018 17:24:28 GMT+0000 (UTC)                         2.0
#
#    financials.gross_churn_min         financials.id      ...       \
# 0                         6.0  RmluYW5jaWFsczo1ODc=      ...
# 1                         1.0  RmluYW5jaWFsczo2MzY=      ...
# 2                         6.0  RmluYW5jaWFsczoyNTE=      ...
# 3                         NaN  RmluYW5jaWFsczo3MjY=      ...
# 4                         1.0  RmluYW5jaWFsczo2Mzc=      ...
#
#    podcast.guest.kids  podcast.guest.married  podcast.guest.name  \
# 0                 NaN                    NaN         Alex Berman
# 1                 0.0                     No          Aki Balogh
# 2                 3.0                    Yes         Todd Fisher
# 3                 NaN                    NaN         Prem Bhatia
# 4                 4.0                    Yes        John Oechsle
#
#                                    podcast.guest.url        podcast.id  \
# 0                           http://inspirebeats.com/  UG9kY2FzdDoxMjc=
# 1             https://www.linkedin.com/in/akibalogh/  UG9kY2FzdDoyNzQ=
# 2           https://www.linkedin.com/in/toddafisher/  UG9kY2FzdDoyMTM=
# 3  https://twitter.com/PremCBhatia?ref_src=twsrc%...  UG9kY2FzdDo1NQ==
# 4          https://www.linkedin.com/in/hjohnoechsle/  UG9kY2FzdDozMDg=
#
#                                          podcast.url  private  \
# 0  https://soundcloud.com/nathan-latka/ep-354-1-3...    False
# 1                                                NaN    False
# 2  https://soundcloud.com/nathan-latka/805-saas-3...    False
# 3  https://soundcloud.com/nathan-latka/ep-267-qui...    False
# 4                                                NaN    False
#
#         sub_category                          url  year_founded
# 0       Contact Data             inspirebeats.com        2014.0
# 1  Content Marketing  https://www.marketmuse.com/        2013.0
# 2              Calls      calltrackingmetrics.com        2012.0
# 3           Training                  cooleaf.com        2012.0
# 4                CRM            www.swiftpage.com        2001.0
#
# [5 rows x 47 columns]

# %%
df_subset = SaaS_df.dropna(subset=['sub_category', 'industry','name','podcast.guest.favorite_book_name'])
#df_subset = df_subset[df_subset['num_employees'] < 2000]
df_subset.head()
# Out:
#    financials.arpu_max  financials.arpu_min  financials.arr_max  \
# 0               1899.0               1899.0          15951600.0
# 1               5000.0               5000.0           4800000.0
# 2                 19.0                 19.0          14400000.0
# 3               2000.0               2000.0           1000000.0
# 4                150.0                100.0         100000000.0
#
#    financials.arr_min  financials.cac_max  financials.cac_min  \
# 0          15951600.0                40.0                40.0
# 1           4200000.0              9000.0              9000.0
# 2          14400000.0               600.0                60.0
# 3            624000.0                 NaN                 NaN
# 4                 NaN               900.0               750.0
#
#                      financials.created_at  financials.gross_churn_max  \
# 0  Wed Feb 21 2018 11:57:07 GMT+0000 (UTC)                         6.0
# 1  Fri Feb 23 2018 17:15:59 GMT+0000 (UTC)                         1.0
# 2  Tue Oct 24 2017 22:58:12 GMT+0000 (UTC)                         6.0
# 3  Tue Feb 27 2018 15:44:13 GMT+0000 (UTC)                         1.0
# 4  Fri Feb 23 2018 17:24:28 GMT+0000 (UTC)                         2.0
#
#    financials.gross_churn_min         financials.id      ...       \
# 0                         6.0  RmluYW5jaWFsczo1ODc=      ...
# 1                         1.0  RmluYW5jaWFsczo2MzY=      ...
# 2                         6.0  RmluYW5jaWFsczoyNTE=      ...
# 3                         NaN  RmluYW5jaWFsczo3MjY=      ...
# 4                         1.0  RmluYW5jaWFsczo2Mzc=      ...
#
#    podcast.guest.kids  podcast.guest.married  podcast.guest.name  \
# 0                 NaN                    NaN         Alex Berman
# 1                 0.0                     No          Aki Balogh
# 2                 3.0                    Yes         Todd Fisher
# 3                 NaN                    NaN         Prem Bhatia
# 4                 4.0                    Yes        John Oechsle
#
#                                    podcast.guest.url        podcast.id  \
# 0                           http://inspirebeats.com/  UG9kY2FzdDoxMjc=
# 1             https://www.linkedin.com/in/akibalogh/  UG9kY2FzdDoyNzQ=
# 2           https://www.linkedin.com/in/toddafisher/  UG9kY2FzdDoyMTM=
# 3  https://twitter.com/PremCBhatia?ref_src=twsrc%...  UG9kY2FzdDo1NQ==
# 4          https://www.linkedin.com/in/hjohnoechsle/  UG9kY2FzdDozMDg=
#
#                                          podcast.url  private  \
# 0  https://soundcloud.com/nathan-latka/ep-354-1-3...    False
# 1                                                NaN    False
# 2  https://soundcloud.com/nathan-latka/805-saas-3...    False
# 3  https://soundcloud.com/nathan-latka/ep-267-qui...    False
# 4                                                NaN    False
#
#         sub_category                          url  year_founded
# 0       Contact Data             inspirebeats.com        2014.0
# 1  Content Marketing  https://www.marketmuse.com/        2013.0
# 2              Calls      calltrackingmetrics.com        2012.0
# 3           Training                  cooleaf.com        2012.0
# 4                CRM            www.swiftpage.com        2001.0
#
# [5 rows x 47 columns]

# %%
SaaS_df.T
# Out:
#                                                                                 0    \
# financials.arpu_max                                                            1899
# financials.arpu_min                                                            1899
# financials.arr_max                                                      1.59516e+07
# financials.arr_min                                                      1.59516e+07
# financials.cac_max                                                               40
# financials.cac_min                                                               40
# financials.created_at                       Wed Feb 21 2018 11:57:07 GMT+0000 (UTC)
# financials.gross_churn_max                                                        6
# financials.gross_churn_min                                                        6
# financials.id                                                  RmluYW5jaWFsczo1ODc=
# financials.ltv_cac                                                            791.4
# financials.ltv_dollars                                                        31656
# financials.ltv_months                                                            16
# financials.mrr_max                                                       1.3293e+06
# financials.mrr_min                                                       1.3293e+06
# financials.num_customers_max                                                    700
# financials.num_customers_min                                                    700
# financials.raised                                                                 0
# financials.revenue_2016                                                    15951600
# financials.revenue_2017                                                         NaN
# financials.updated_at                       Mon May 30 2016 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToxMjc=
# industry                                                           Sales Automation
# location                                                              San Francisco
# logo_url                                 https://logo.clearbit.com/inspirebeats.com
# name                                                                   InspireBeats
# num_employees                                                                    21
# podcast.guest.advice                                                            NaN
# podcast.guest.age                                                                24
# podcast.guest.favorite_book_name                                           10X Rule
# podcast.guest.favorite_book_url   https://www.amazon.com/gp/product/0470627603/r...
# podcast.guest.favorite_ceo_name                                      Chris Hardwick
# podcast.guest.favorite_ceo_url                   http://nerdist.com/chris-hardwick/
# podcast.guest.favorite_tool_name                                             Streak
# podcast.guest.favorite_tool_url                             https://www.streak.com/
# podcast.guest.hours_sleep                                                       yes
# podcast.guest.id                                                   Rm91bmRlcjoxMjc=
# podcast.guest.kids                                                              NaN
# podcast.guest.married                                                           NaN
# podcast.guest.name                                                      Alex Berman
# podcast.guest.url                                          http://inspirebeats.com/
# podcast.id                                                         UG9kY2FzdDoxMjc=
# podcast.url                       https://soundcloud.com/nathan-latka/ep-354-1-3...
# private                                                                       False
# sub_category                                                           Contact Data
# url                                                                inspirebeats.com
# year_founded                                                                   2014
#
#                                                                                 1    \
# financials.arpu_max                                                            5000
# financials.arpu_min                                                            5000
# financials.arr_max                                                          4.8e+06
# financials.arr_min                                                          4.2e+06
# financials.cac_max                                                             9000
# financials.cac_min                                                             9000
# financials.created_at                       Fri Feb 23 2018 17:15:59 GMT+0000 (UTC)
# financials.gross_churn_max                                                        1
# financials.gross_churn_min                                                        1
# financials.id                                                  RmluYW5jaWFsczo2MzY=
# financials.ltv_cac                                                            55.56
# financials.ltv_dollars                                                       500000
# financials.ltv_months                                                           100
# financials.mrr_max                                                           400000
# financials.mrr_min                                                           350000
# financials.num_customers_max                                                    NaN
# financials.num_customers_min                                                    100
# financials.raised                                                             4e+06
# financials.revenue_2016                                                      420000
# financials.revenue_2017                                                     4.2e+06
# financials.updated_at                       Tue Jan 16 2018 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToyODA=
# industry                                                       Marketing Automation
# location                                                                 Boston, MA
# logo_url                          https://upload.wikimedia.org/wikipedia/commons...
# name                                                                     MarketMuse
# num_employees                                                                    22
# podcast.guest.advice                                               Take more risks.
# podcast.guest.age                                                                32
# podcast.guest.favorite_book_name                   What i wish i knew when i was 20
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                                 NaN
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                               Zoom
# podcast.guest.favorite_tool_url                                    https://zoom.us/
# podcast.guest.hours_sleep                                                         6
# podcast.guest.id                                                   Rm91bmRlcjoyNzQ=
# podcast.guest.kids                                                                0
# podcast.guest.married                                                            No
# podcast.guest.name                                                       Aki Balogh
# podcast.guest.url                            https://www.linkedin.com/in/akibalogh/
# podcast.id                                                         UG9kY2FzdDoyNzQ=
# podcast.url                                                                     NaN
# private                                                                       False
# sub_category                                                      Content Marketing
# url                                                     https://www.marketmuse.com/
# year_founded                                                                   2013
#
#                                                                                 2    \
# financials.arpu_max                                                              19
# financials.arpu_min                                                              19
# financials.arr_max                                                         1.44e+07
# financials.arr_min                                                         1.44e+07
# financials.cac_max                                                              600
# financials.cac_min                                                               60
# financials.created_at                       Tue Oct 24 2017 22:58:12 GMT+0000 (UTC)
# financials.gross_churn_max                                                        6
# financials.gross_churn_min                                                        6
# financials.id                                                  RmluYW5jaWFsczoyNTE=
# financials.ltv_cac                                                            10.83
# financials.ltv_dollars                                                          650
# financials.ltv_months                                                            17
# financials.mrr_max                                                          1.2e+06
# financials.mrr_min                                                          1.2e+06
# financials.num_customers_max                                                    NaN
# financials.num_customers_min                                                  30000
# financials.raised                                                                 0
# financials.revenue_2016                                                     8000000
# financials.revenue_2017                                                    1.44e+07
# financials.updated_at                       Tue Oct 24 2017 22:58:12 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToyMTM=
# industry                                                           Sales Automation
# location                                                                  Annapolis
# logo_url                          https://logo.clearbit.com/calltrackingmetrics.com
# name                                                          Call Tracking Metrics
# num_employees                                                                    23
# podcast.guest.advice                                         Get your shit together
# podcast.guest.age                                                                36
# podcast.guest.favorite_book_name                                               None
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                           Elon Musk
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                           Hurli.it
# podcast.guest.favorite_tool_url                                                 NaN
# podcast.guest.hours_sleep                                                         6
# podcast.guest.id                                                   Rm91bmRlcjoyMTM=
# podcast.guest.kids                                                                3
# podcast.guest.married                                                           Yes
# podcast.guest.name                                                      Todd Fisher
# podcast.guest.url                          https://www.linkedin.com/in/toddafisher/
# podcast.id                                                         UG9kY2FzdDoyMTM=
# podcast.url                       https://soundcloud.com/nathan-latka/805-saas-3...
# private                                                                       False
# sub_category                                                                  Calls
# url                                                         calltrackingmetrics.com
# year_founded                                                                   2012
#
#                                                                                 3    \
# financials.arpu_max                                                            2000
# financials.arpu_min                                                            2000
# financials.arr_max                                                            1e+06
# financials.arr_min                                                           624000
# financials.cac_max                                                              NaN
# financials.cac_min                                                              NaN
# financials.created_at                       Tue Feb 27 2018 15:44:13 GMT+0000 (UTC)
# financials.gross_churn_max                                                        1
# financials.gross_churn_min                                                      NaN
# financials.id                                                  RmluYW5jaWFsczo3MjY=
# financials.ltv_cac                                                              NaN
# financials.ltv_dollars                                                        96000
# financials.ltv_months                                                            48
# financials.mrr_max                                                            88000
# financials.mrr_min                                                            52000
# financials.num_customers_max                                                     26
# financials.num_customers_min                                                     26
# financials.raised                                                            800000
# financials.revenue_2016                                                      624000
# financials.revenue_2017                                                         NaN
# financials.updated_at                       Tue Mar 15 2016 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueTo1NQ==
# industry                                                            Human Resources
# location                                                                        NaN
# logo_url                                      https://logo.clearbit.com/cooleaf.com
# name                                                                        Cooleaf
# num_employees                                                                    11
# podcast.guest.advice                         Do it sooner. You’ll learn on the job.
# podcast.guest.age                                                               NaN
# podcast.guest.favorite_book_name                                       The Alliance
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                       Dharmesh Shah
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                           LinkedIn
# podcast.guest.favorite_tool_url                                                 NaN
# podcast.guest.hours_sleep                                                       NaN
# podcast.guest.id                                                   Rm91bmRlcjo1NQ==
# podcast.guest.kids                                                              NaN
# podcast.guest.married                                                           NaN
# podcast.guest.name                                                      Prem Bhatia
# podcast.guest.url                 https://twitter.com/PremCBhatia?ref_src=twsrc%...
# podcast.id                                                         UG9kY2FzdDo1NQ==
# podcast.url                       https://soundcloud.com/nathan-latka/ep-267-qui...
# private                                                                       False
# sub_category                                                               Training
# url                                                                     cooleaf.com
# year_founded                                                                   2012
#
#                                                                                4    \
# financials.arpu_max                                                            150
# financials.arpu_min                                                            100
# financials.arr_max                                                           1e+08
# financials.arr_min                                                             NaN
# financials.cac_max                                                             900
# financials.cac_min                                                             750
# financials.created_at                      Fri Feb 23 2018 17:24:28 GMT+0000 (UTC)
# financials.gross_churn_max                                                       2
# financials.gross_churn_min                                                       1
# financials.id                                                 RmluYW5jaWFsczo2Mzc=
# financials.ltv_cac                                                           14.64
# financials.ltv_dollars                                                       10980
# financials.ltv_months                                                         73.2
# financials.mrr_max                                                     8.33333e+06
# financials.mrr_min                                                             NaN
# financials.num_customers_max                                                   NaN
# financials.num_customers_min                                                 85000
# financials.raised                                                              NaN
# financials.revenue_2016                                                   65000000
# financials.revenue_2017                                                      1e+08
# financials.updated_at                      Tue Jan 16 2018 00:00:00 GMT+0000 (UTC)
# id                                                                Q29tcGFueTozMTQ=
# industry                                                          Sales Automation
# location                                                       Scottsdale, Arizona
# logo_url                               https://logo.clearbit.com/www.swiftpage.com
# name                                                                     Swiftpage
# num_employees                                                                  170
# podcast.guest.advice              Raise some capital and start a company early on.
# podcast.guest.age                                                               55
# podcast.guest.favorite_book_name     Blink: The Power of Thinking Without Thinking
# podcast.guest.favorite_book_url                                                NaN
# podcast.guest.favorite_ceo_name                                        Jerre Stead
# podcast.guest.favorite_ceo_url                                                 NaN
# podcast.guest.favorite_tool_name                                           Twitter
# podcast.guest.favorite_tool_url                                                NaN
# podcast.guest.hours_sleep                                                      6.5
# podcast.guest.id                                                  Rm91bmRlcjozMDg=
# podcast.guest.kids                                                               4
# podcast.guest.married                                                          Yes
# podcast.guest.name                                                    John Oechsle
# podcast.guest.url                        https://www.linkedin.com/in/hjohnoechsle/
# podcast.id                                                        UG9kY2FzdDozMDg=
# podcast.url                                                                    NaN
# private                                                                      False
# sub_category                                                                   CRM
# url                                                              www.swiftpage.com
# year_founded                                                                  2001
#
#                                                                                 5    \
# financials.arpu_max                                                            1800
# financials.arpu_min                                                            1800
# financials.arr_max                                                         1.08e+06
# financials.arr_min                                                         1.08e+06
# financials.cac_max                                                             2000
# financials.cac_min                                                             2000
# financials.created_at                       Wed Dec 07 2016 00:00:00 GMT+0000 (UTC)
# financials.gross_churn_max                                                        8
# financials.gross_churn_min                                                        8
# financials.id                                                  RmluYW5jaWFsczoxMjE=
# financials.ltv_cac                                                            11.25
# financials.ltv_dollars                                                        22500
# financials.ltv_months                                                          12.5
# financials.mrr_max                                                            90000
# financials.mrr_min                                                            90000
# financials.num_customers_max                                                     50
# financials.num_customers_min                                                     50
# financials.raised                                                           1.1e+06
# financials.revenue_2016                                                     1080000
# financials.revenue_2017                                                         NaN
# financials.updated_at                       Wed Dec 07 2016 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToxMjE=
# industry                                                           Sales Automation
# location                                                             Durham, Remote
# logo_url                          https://www.revboss.com/ui/img/logos/revboss-w...
# name                                                                        RevBoss
# num_employees                                                                    12
# podcast.guest.advice              “To not worry so much about the long term—that...
# podcast.guest.age                                                                36
# podcast.guest.favorite_book_name                  The Hard Things About Hard Things
# podcast.guest.favorite_book_url                              http://amzn.to/2j6LjNk
# podcast.guest.favorite_ceo_name                                     Matt Williamson
# podcast.guest.favorite_ceo_url           https://www.linkedin.com/in/mattwilliamson
# podcast.guest.favorite_tool_name                                             Stripe
# podcast.guest.favorite_tool_url                                 https://stripe.com/
# podcast.guest.hours_sleep                                                        No
# podcast.guest.id                                                   Rm91bmRlcjoxMjE=
# podcast.guest.kids                                                                3
# podcast.guest.married                                                           NaN
# podcast.guest.name                                                       Eric Boggs
# podcast.guest.url                             https://www.linkedin.com/in/ericboggs
# podcast.id                                                         UG9kY2FzdDoxMjE=
# podcast.url                       https://soundcloud.com/nathan-latka/ep-544-rev...
# private                                                                       False
# sub_category                                                           Contact Data
# url                                                         http://www.revboss.com/
# year_founded                                                                   2016
#
#                                                                                 6    \
# financials.arpu_max                                                              41
# financials.arpu_min                                                              41
# financials.arr_max                                                           300000
# financials.arr_min                                                           300000
# financials.cac_max                                                               50
# financials.cac_min                                                               50
# financials.created_at                       Sun Jun 05 2016 00:00:00 GMT+0000 (UTC)
# financials.gross_churn_max                                                      NaN
# financials.gross_churn_min                                                      NaN
# financials.id                                                  RmluYW5jaWFsczoxMTM=
# financials.ltv_cac                                                              NaN
# financials.ltv_dollars                                                          NaN
# financials.ltv_months                                                           NaN
# financials.mrr_max                                                            25000
# financials.mrr_min                                                            25000
# financials.num_customers_max                                                    600
# financials.num_customers_min                                                    600
# financials.raised                                                           4.5e+06
# financials.revenue_2016                                                      300000
# financials.revenue_2017                                                         NaN
# financials.updated_at                       Sun Jun 05 2016 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToxMTM=
# industry                                                                Real Estate
# location                                                              San Francisco
# logo_url                                       https://logo.clearbit.com/spacer.com
# name                                                                         Spacer
# num_employees                                                                    17
# podcast.guest.advice                                                            NaN
# podcast.guest.age                                                                26
# podcast.guest.favorite_book_name                       Hard thing about hard things
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                                 NaN
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                                NaN
# podcast.guest.favorite_tool_url                                                 NaN
# podcast.guest.hours_sleep                                                       Yes
# podcast.guest.id                                                   Rm91bmRlcjoxMTM=
# podcast.guest.kids                                                              NaN
# podcast.guest.married                                                           NaN
# podcast.guest.name                                                 Jonathan Gillons
# podcast.guest.url                                                               NaN
# podcast.id                                                         UG9kY2FzdDoxMTM=
# podcast.url                       https://soundcloud.com/nathan-latka/ep-364-300...
# private                                                                       False
# sub_category                                                            Real Estate
# url                                                                      spacer.com
# year_founded                                                                   2013
#
#                                                                                7    \
# financials.arpu_max                                                             49
# financials.arpu_min                                                              8
# financials.arr_max                                                         1.8e+06
# financials.arr_min                                                         1.2e+06
# financials.cac_max                                                             NaN
# financials.cac_min                                                             NaN
# financials.created_at                      Sat Oct 27 2018 13:57:59 GMT+0000 (UTC)
# financials.gross_churn_max                                                     NaN
# financials.gross_churn_min                                                     NaN
# financials.id                                                 RmluYW5jaWFsczoxMjE1
# financials.ltv_cac                                                             NaN
# financials.ltv_dollars                                                        1000
# financials.ltv_months                                                           18
# financials.mrr_max                                                          150000
# financials.mrr_min                                                          100000
# financials.num_customers_max                                                 10000
# financials.num_customers_min                                                 10000
# financials.raised                                                           850000
# financials.revenue_2016                                                     750000
# financials.revenue_2017                                                    1.2e+06
# financials.updated_at                      Thu Sep 27 2018 00:00:00 GMT+0000 (UTC)
# id                                                                Q29tcGFueTozMjQ=
# industry                                                                      Misc
# location                                                 New York, NY - Costa Rica
# logo_url                          https://logo.clearbit.com/https://slidebean.com/
# name                                                                     SlideBean
# num_employees                                                                   20
# podcast.guest.advice                                      Start a business faster.
# podcast.guest.age                                                               29
# podcast.guest.favorite_book_name                                          Traction
# podcast.guest.favorite_book_url                                                NaN
# podcast.guest.favorite_ceo_name                                   Josh Baremetrics
# podcast.guest.favorite_ceo_url                                                 NaN
# podcast.guest.favorite_tool_name                                          Intercom
# podcast.guest.favorite_tool_url                                                NaN
# podcast.guest.hours_sleep                                                        5
# podcast.guest.id                                                  Rm91bmRlcjozMTg=
# podcast.guest.kids                                                               1
# podcast.guest.married                                                          Yes
# podcast.guest.name                                                    Jose Cayasso
# podcast.guest.url                         https://www.linkedin.com/in/cayajose/en/
# podcast.id                                                        UG9kY2FzdDozMTg=
# podcast.url                                                                    NaN
# private                                                                      False
# sub_category                                                         Presentations
# url                                                         https://slidebean.com/
# year_founded                                                                  2014
#
#                                                                                 8    \
# financials.arpu_max                                                            4200
# financials.arpu_min                                                            4200
# financials.arr_max                                                            3e+07
# financials.arr_min                                                            1e+07
# financials.cac_max                                                            25000
# financials.cac_min                                                            25000
# financials.created_at                       Fri Jul 27 2018 09:38:58 GMT+0000 (UTC)
# financials.gross_churn_max                                                        1
# financials.gross_churn_min                                                      NaN
# financials.id                                                  RmluYW5jaWFsczo4NzA=
# financials.ltv_cac                                                               12
# financials.ltv_dollars                                                       300000
# financials.ltv_months                                                            72
# financials.mrr_max                                                          2.5e+06
# financials.mrr_min                                                           833000
# financials.num_customers_max                                                    NaN
# financials.num_customers_min                                                    200
# financials.raised                                                           2.9e+07
# financials.revenue_2016                                                     5000000
# financials.revenue_2017                                                   9.996e+06
# financials.updated_at                       Tue May 01 2018 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueTo0NTU=
# industry                                                       Marketing Automation
# location                                                         New York, New York
# logo_url                          https://logo.clearbit.com/https://www.wochit.com/
# name                                                                         Wochit
# num_employees                                                                    60
# podcast.guest.advice                              Be less arrogant and listen more.
# podcast.guest.age                                                                46
# podcast.guest.favorite_book_name                                 Crossing The Chasm
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                          Jack walls
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                              Canva
# podcast.guest.favorite_tool_url                                                 NaN
# podcast.guest.hours_sleep                                                         6
# podcast.guest.id                                                   Rm91bmRlcjo0NDU=
# podcast.guest.kids                                                                4
# podcast.guest.married                                                           Yes
# podcast.guest.name                                                    Dror Ginzberg
# podcast.guest.url                         https://www.linkedin.com/in/drorginzberg/
# podcast.id                                                         UG9kY2FzdDo0NDU=
# podcast.url                                                                     NaN
# private                                                                       False
# sub_category                                                        Video Marketing
# url                                                         https://www.wochit.com/
# year_founded                                                                   2012
#
#                                                                                 9    \
# financials.arpu_max                                                            2500
# financials.arpu_min                                                            2500
# financials.arr_max                                                           600000
# financials.arr_min                                                           600000
# financials.cac_max                                                              NaN
# financials.cac_min                                                              NaN
# financials.created_at                       Wed Feb 21 2018 15:51:57 GMT+0000 (UTC)
# financials.gross_churn_max                                                      NaN
# financials.gross_churn_min                                                      NaN
# financials.id                                                  RmluYW5jaWFsczo1OTQ=
# financials.ltv_cac                                                              NaN
# financials.ltv_dollars                                                          NaN
# financials.ltv_months                                                           NaN
# financials.mrr_max                                                            50000
# financials.mrr_min                                                            50000
# financials.num_customers_max                                                     20
# financials.num_customers_min                                                     20
# financials.raised                                                                 0
# financials.revenue_2016                                                      600000
# financials.revenue_2017                                                         NaN
# financials.updated_at                       Thu Nov 10 2016 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToxMzc=
# industry                                                           Sales Automation
# location                                                   UK, Ireland, New Zealand
# logo_url                                      https://logo.clearbit.com/leadiro.com
# name                                                                        Leadiro
# num_employees                                                                     6
# podcast.guest.advice              “Work hard because nothing happens overnight a...
# podcast.guest.age                                                                40
# podcast.guest.favorite_book_name                          The Magic of Thinking Big
# podcast.guest.favorite_book_url   https://www.amazon.com/Magic-Thinking-Big-Davi...
# podcast.guest.favorite_ceo_name                                                 NaN
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                         SimilarWeb
# podcast.guest.favorite_tool_url                         https://www.similarweb.com/
# podcast.guest.hours_sleep                                                       Yes
# podcast.guest.id                                                   Rm91bmRlcjoxMzc=
# podcast.guest.kids                                                                2
# podcast.guest.married                                                           NaN
# podcast.guest.name                                                       Ian Cullen
# podcast.guest.url                              https://uk.linkedin.com/in/iancullen
# podcast.id                                                         UG9kY2FzdDoxMzc=
# podcast.url                                                                     NaN
# private                                                                       False
# sub_category                                                           Contact Data
# url                                                                     leadiro.com
# year_founded                                                                   2016
#
#                                                         ...                          \
# financials.arpu_max                                     ...
# financials.arpu_min                                     ...
# financials.arr_max                                      ...
# financials.arr_min                                      ...
# financials.cac_max                                      ...
# financials.cac_min                                      ...
# financials.created_at                                   ...
# financials.gross_churn_max                              ...
# financials.gross_churn_min                              ...
# financials.id                                           ...
# financials.ltv_cac                                      ...
# financials.ltv_dollars                                  ...
# financials.ltv_months                                   ...
# financials.mrr_max                                      ...
# financials.mrr_min                                      ...
# financials.num_customers_max                            ...
# financials.num_customers_min                            ...
# financials.raised                                       ...
# financials.revenue_2016                                 ...
# financials.revenue_2017                                 ...
# financials.updated_at                                   ...
# id                                                      ...
# industry                                                ...
# location                                                ...
# logo_url                                                ...
# name                                                    ...
# num_employees                                           ...
# podcast.guest.advice                                    ...
# podcast.guest.age                                       ...
# podcast.guest.favorite_book_name                        ...
# podcast.guest.favorite_book_url                         ...
# podcast.guest.favorite_ceo_name                         ...
# podcast.guest.favorite_ceo_url                          ...
# podcast.guest.favorite_tool_name                        ...
# podcast.guest.favorite_tool_url                         ...
# podcast.guest.hours_sleep                               ...
# podcast.guest.id                                        ...
# podcast.guest.kids                                      ...
# podcast.guest.married                                   ...
# podcast.guest.name                                      ...
# podcast.guest.url                                       ...
# podcast.id                                              ...
# podcast.url                                             ...
# private                                                 ...
# sub_category                                            ...
# url                                                     ...
# year_founded                                            ...
#
#                                                                                 596  \
# financials.arpu_max                                                            1000
# financials.arpu_min                                                            1000
# financials.arr_max                                                            9e+06
# financials.arr_min                                                            9e+06
# financials.cac_max                                                             2000
# financials.cac_min                                                             1500
# financials.created_at                       Tue Sep 11 2018 08:44:12 GMT+0000 (UTC)
# financials.gross_churn_max                                                      NaN
# financials.gross_churn_min                                                      NaN
# financials.id                                                  RmluYW5jaWFsczo5MzI=
# financials.ltv_cac                                                              NaN
# financials.ltv_dollars                                                          NaN
# financials.ltv_months                                                           NaN
# financials.mrr_max                                                           750000
# financials.mrr_min                                                           750000
# financials.num_customers_max                                                    NaN
# financials.num_customers_min                                                    800
# financials.raised                                                             2e+06
# financials.revenue_2016                                                     9000000
# financials.revenue_2017                                                       9e+06
# financials.updated_at                       Tue Aug 07 2018 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueTo1MDk=
# industry                                                           Sales Automation
# ...
# financials.cac_max                                                        NaN
# financials.cac_min                                                        NaN
# financials.created_at                 Fri May 18 2018 09:05:49 GMT+0000 (UTC)
# financials.gross_churn_max                                                  1
# financials.gross_churn_min                                                NaN
# financials.id                                            RmluYW5jaWFsczo3OTI=
# financials.ltv_cac                                                        NaN
# financials.ltv_dollars                                                   4900
# financials.ltv_months                                                     100
# financials.mrr_max                                                     500000
# financials.mrr_min                                                      50000
# financials.num_customers_max                                             1000
# financials.num_customers_min                                             1000
# financials.raised                                                      224000
# financials.revenue_2016                                                600000
# financials.revenue_2017                                                600000
# financials.updated_at                 Thu Mar 30 2017 00:00:00 GMT+0000 (UTC)
# id                                                           Q29tcGFueTozODU=
# industry                                                                 Misc
# location                                                        Sunnyvale, CA
# logo_url                          https://logo.clearbit.com/https://vsee.com/
# name                                                                     Vsee
# num_employees                                                              52
# podcast.guest.advice                        Don't be as naive and clueless.\n
# podcast.guest.age                                                         NaN
# podcast.guest.favorite_book_name                                  Zero to One
# podcast.guest.favorite_book_url                                           NaN
# podcast.guest.favorite_ceo_name                                  Marc Benioff
# podcast.guest.favorite_ceo_url                                            NaN
# podcast.guest.favorite_tool_name                                   Rapportive
# podcast.guest.favorite_tool_url                                           NaN
# podcast.guest.hours_sleep                                                 4.5
# podcast.guest.id                                             Rm91bmRlcjozNzU=
# podcast.guest.kids                                                          2
# podcast.guest.married                                                     Yes
# podcast.guest.name                                                Milton Chen
# podcast.guest.url                     https://www.linkedin.com/in/miltonchen/
# podcast.id                                                   UG9kY2FzdDozNzU=
# podcast.url                                                               NaN
# private                                                                 False
# sub_category                                                       Healthcare
# url                                                         https://vsee.com/
# year_founded                                                             2008
#
#                                                                                 603  \
# financials.arpu_max                                                            1500
# financials.arpu_min                                                            1500
# financials.arr_max                                                            36000
# financials.arr_min                                                            36000
# financials.cac_max                                                             5000
# financials.cac_min                                                             5000
# financials.created_at                       Thu Mar 29 2018 17:22:25 GMT+0000 (UTC)
# financials.gross_churn_max                                                      NaN
# financials.gross_churn_min                                                      NaN
# financials.id                                                  RmluYW5jaWFsczo3MzI=
# financials.ltv_cac                                                              NaN
# financials.ltv_dollars                                                          NaN
# financials.ltv_months                                                           NaN
# financials.mrr_max                                                             3000
# financials.mrr_min                                                             3000
# financials.num_customers_max                                                      2
# financials.num_customers_min                                                      2
# financials.raised                                                             25000
# financials.revenue_2016                                                       36000
# financials.revenue_2017                                                       36000
# financials.updated_at                       Tue Mar 27 2018 00:00:00 GMT+0000 (UTC)
# id                                                                 Q29tcGFueTozMzA=
# industry                                                                Marketplace
# location                                                        Mexico City, Mexico
# logo_url                            https://logo.clearbit.com/http://bluerabbit.io/
# name                                                                     BLUErabbit
# num_employees                                                                     7
# podcast.guest.advice              It doe not matter how hard it will get, you wi...
# podcast.guest.age                                                                35
# podcast.guest.favorite_book_name                                             Rework
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                          Bill Gates
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                              Slack
# podcast.guest.favorite_tool_url                                                 NaN
# podcast.guest.hours_sleep                                                       7.5
# podcast.guest.id                                                   Rm91bmRlcjozMjQ=
# podcast.guest.kids                                                                0
# podcast.guest.married                                                           Yes
# podcast.guest.name                                                  Bernardo Letayf
# podcast.guest.url                       https://www.linkedin.com/in/bernardoletayf/
# podcast.id                                                         UG9kY2FzdDozMjQ=
# podcast.url                                                                     NaN
# private                                                                       False
# sub_category                                                               Teaching
# url                                                           http://bluerabbit.io/
# year_founded                                                                   2017
#
#                                                                                 604  \
# financials.arpu_max                                                              50
# financials.arpu_min                                                              50
# financials.arr_max                                                         1.44e+06
# financials.arr_min                                                         1.44e+06
# financials.cac_max                                                              100
# financials.cac_min                                                              100
# financials.created_at                       Tue Nov 28 2017 22:06:07 GMT+0000 (UTC)
# financials.gross_churn_max                                                        5
# financials.gross_churn_min                                                        5
# financials.id                                                  RmluYW5jaWFsczozMDA=
# financials.ltv_cac                                                               10
# financials.ltv_dollars                                                         1000
# financials.ltv_months                                                            20
# financials.mrr_max                                                           120000
# financials.mrr_min                                                           120000
# financials.num_customers_max                                                   2400
# financials.num_customers_min                                                   2400
# financials.raised                                                             4e+06
# financials.revenue_2016                                                     1728000
# financials.revenue_2017                                                    1.44e+06
# financials.updated_at                       Tue Nov 28 2017 22:06:07 GMT+0000 (UTC)
# id                                                                 Q29tcGFueTo4Nw==
# industry                                                       Marketing Automation
# location                                                                    Detroit
# logo_url                                      https://logo.clearbit.com/waymark.com
# name                                                                        Waymark
# num_employees                                                                    13
# podcast.guest.advice                                                            NaN
# podcast.guest.age                                                                32
# podcast.guest.favorite_book_name                                     The Third Wave
# podcast.guest.favorite_book_url   https://www.amazon.com/gp/product/150113258X/r...
# podcast.guest.favorite_ceo_name                                     Mark Zuckerberg
# podcast.guest.favorite_ceo_url        https://en.wikipedia.org/wiki/Mark_Zuckerberg
# podcast.guest.favorite_tool_name                                            HipChat
# podcast.guest.favorite_tool_url                            https://www.hipchat.com/
# podcast.guest.hours_sleep                                                       Yes
# podcast.guest.id                                                   Rm91bmRlcjo4Nw==
# podcast.guest.kids                                                              NaN
# podcast.guest.married                                                           NaN
# podcast.guest.name                                                    Nathan Labenz
# podcast.guest.url                            https://www.facebook.com/nathan.labenz
# podcast.id                                                         UG9kY2FzdDo4Nw==
# podcast.url                                                                     NaN
# private                                                                       False
# sub_category                                                 Social Media Marketing
# url                                                                     waymark.com
# year_founded                                                                   2014
#
#                                                                                 605
# financials.arpu_max                                                             NaN
# financials.arpu_min                                                              50
# financials.arr_max                                                              NaN
# financials.arr_min                                                           600000
# financials.cac_max                                                              NaN
# financials.cac_min                                                              NaN
# financials.created_at                       Sat Dec 02 2017 13:12:59 GMT+0000 (UTC)
# financials.gross_churn_max                                                      NaN
# financials.gross_churn_min                                                        4
# financials.id                                                  RmluYW5jaWFsczozMDU=
# financials.ltv_cac                                                              NaN
# financials.ltv_dollars                                                         1200
# financials.ltv_months                                                            24
# financials.mrr_max                                                              NaN
# financials.mrr_min                                                            50000
# financials.num_customers_max                                                    NaN
# financials.num_customers_min                                                   1000
# financials.raised                                                             1e+06
# financials.revenue_2016                                                      600000
# financials.revenue_2017                                                      600000
# financials.updated_at                       Sat Dec 02 2017 13:12:59 GMT+0000 (UTC)
# id                                                                 Q29tcGFueToyNDI=
# industry                                                           Sales Automation
# location                                                                        NaN
# logo_url                                    https://logo.clearbit.com/GoSquared.com
# name                                                                      GoSquared
# num_employees                                                                    10
# podcast.guest.advice              It takes a long time to build a meaningful bus...
# podcast.guest.age                                                                26
# podcast.guest.favorite_book_name                                             Tribes
# podcast.guest.favorite_book_url                                                 NaN
# podcast.guest.favorite_ceo_name                                          Hiten Shah
# podcast.guest.favorite_ceo_url                                                  NaN
# podcast.guest.favorite_tool_name                                             Things
# podcast.guest.favorite_tool_url                                                 NaN
# podcast.guest.hours_sleep                                                         6
# podcast.guest.id                                                   Rm91bmRlcjoyMzU=
# podcast.guest.kids                                                                0
# podcast.guest.married                                                            No
# podcast.guest.name                                                       James Gill
# podcast.guest.url                           https://www.linkedin.com/in/jamesjgill/
# podcast.id                                                         UG9kY2FzdDoyMzU=
# podcast.url                       https://soundcloud.com/nathan-latka/861-saas-s...
# private                                                                       False
# sub_category                                     Customer Engagement and Onboarding
# url                                                                   GoSquared.com
# year_founded                                                                   2006
#
# [47 rows x 606 columns]

# %%
SP_500_data = "Resources/constituents-financials_csv.csv"
SP_500_df = pd.read_csv(SP_500_data)
SP_500_df.head()
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  138721055226
# 1        1.147959            1.70        68.39        48.925   10783419933
# 2        1.908982            0.26        64.60        42.280  102121042306
# 3        2.499560            3.29       125.86        60.050  181386347059
# 4        1.714470            5.44       162.60       114.820   98765855553
#
#          EBITDA  Price/Sales  Price/Book  \
# 0  9.048000e+09     4.390271       11.34
# 1  6.010000e+08     3.575483        6.35
# 2  5.744000e+09     3.740480        3.19
# 3  1.031000e+10     6.291571       26.14
# 4  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
SaaS_1000 = "Resources/saas1000.csv"
SaaS_1000_df = pd.read_csv(SaaS_1000)
SaaS_1000_df.head()
# Out:
#    2019rank                name             url  \
# 0       1.0           Pitchbook   Pitchbook.com
# 1       2.0              Repsly      repsly.com
# 2       3.0           1Password   1password.com
# 3       4.0  Magnitude Software   magnitude.com
# 4       5.0          MailerLite  mailerlite.com
#
#                                             linkedin     city state country  \
# 0  https://www.linkedin.com/company/pitchbook-dat...  Seattle    WA     NaN
# 1           http://www.linkedin.com/company/salespod   Boston    MA     NaN
# 2  https://www.linkedin.com/company/summit-web-de...      NaN   NaN     NaN
# 3         https://www.linkedin.com/company/magnitude   Austin    TX     NaN
# 4     https://www.linkedin.com/company/marketpro-biz  Vilnius    LT     NaN
#
#           phone interview                                             growth  \
# 0           NaN       NaN                                                NaN
# 1  617.459.9012       NaN  http://www.total-croatia-news.com/business/190...
# 2           NaN       NaN                                                NaN
# 3           NaN       NaN                                                NaN
# 4           NaN       NaN                                                NaN
#
#   leadinvestor  july2018employees  feb2019employees 6monthincrease
# 0  Morningstar               15.0             594.0       3860.00%
# 1    LaunchPad                2.0              67.0       3250.00%
# 2          NaN                2.0              59.0       2850.00%
# 3          NaN               12.0             250.0       1983.33%
# 4          NaN                2.0              40.0       1900.00%
